# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Lendo um conjunto de dados obs: series é uma coluna do dataframe

d = {'col1': [1,2,3],
        'col2': [4,5,6]}
df = pd.DataFrame(data=d)

# %%
df
# Out:
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6

# %%
#data frame from csv -> por padrao o separador do csv é ",", como nesse csv é ;, temos que identificar isso
# https://www.kaggle.com/datasets/aungpyaeap/supermarket-sales
df = pd.read_csv("/content/drive/MyDrive/IMERSIVO PANDAS/Datasets/supermarket_sales1.csv", sep=";", parse_dates=["Date"])

# %%
# Como ler as primeiras X linhas do arquivo
df.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyidaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyidaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyidaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%      Total  \
# 0       Health and beauty       74.69         7  261.415  5.489.715
# 1  Electronic accessories       15.28         5    3.820      80.22
# 2      Home and lifestyle       46.33         7  162.155  3.405.255
# 3       Health and beauty       58.22         8   23.288    489.048
# ...

# %%
df2 = pd.read_csv("/content/drive/MyDrive/IMERSIVO PANDAS/Datasets/supermarket_sales1.csv", sep=";", parse_dates=["Date"])

# %%
df2.head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyidaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%      Total  \
# 0       Health and beauty       74.69         7  261.415  5.489.715
# 1  Electronic accessories       15.28         5    3.820      80.22
# 2      Home and lifestyle       46.33         7  162.155  3.405.255
# 3       Health and beauty       58.22         8   23.288    489.048
# 4       Sports and travel       86.31         7  302.085  6.343.785
#
#         Date   Time      Payment    cogs gross margin percentage  \
# 0 2019-01-05  13:08      Ewallet  522.83           4.761.904.762
# 1 2019-03-08  10:29         Cash   76.40           4.761.904.762
# ...

# %%
df2['Total'] = df2['Total'].replace('.', '', df2['Total'].count('.') - 1)
# Out:
# <ipython-input-19-c4968ef3ead4>:1: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. ser.count(level=1) should use ser.groupby(level=1).count().
#   df2['Total'] = df2['Total'].replace('.', '', df2['Total'].count('.') - 1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-c4968ef3ead4> in <module>
# ----> 1 df2['Total'] = df2['Total'].replace('.', '', df2['Total'].count('.') - 1)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/series.py in count(self, level)
#    1936             )
#    1937             if not isinstance(self.index, MultiIndex):
# -> 1938                 raise ValueError("Series.count level is only valid with a MultiIndex")
#    1939
#    1940         index = self.index
#
# ValueError: Series.count level is only valid with a MultiIndex

# %% [markdown]
# ### Dicionário das variáveis
#
# - Invoice ID = Número de identificação da fatura do recibo de venda gerado por computador
# - Branch = Filial do supercentro (estão disponíveis 3 filiais identificadas por A, B e C).
# - City = Localização de supercentros
# - Customer type = Tipo de clientes, registrados por Associados para clientes com cartão de sócio e Normal e para cliente sem cartão de sócio.
# - Gender = Gênero do cliente
# - Product line = Grupos de categorização geral de itens - Acessórios eletrônicos, Acessórios de moda, Alimentos e bebidas, Saúde e beleza, Casa e estilo de vida, Esportes e viagens
# - Unit price = Preço de cada produto
# - Quantity = Número de produtos comprados pelo cliente
# - Tax 5% = Taxa de imposto de 5% para a compra do cliente
# - Total	= Preço total incluindo impostos
# - Date = Data de compra (Registro disponível de janeiro de 2019 a março de 2019)
# - Time = Horário de compra (10h às 21h)
# - Payment = Pagamento usado pelo cliente para compra (3 métodos estão disponíveis – Dinheiro, Cartão de Crédito e Ewallet)
# - cogs = Custo dos bens vendidos
# - gross margin percentage = Porcentagem de margem bruta
# - gross income = Renda bruta
# - Rating = Classificação da estratificação do cliente em sua experiência geral de compra (numa escala de 1 a 10)

# %%
# 5 ultimas linhas
df.tail(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 964  233-67-5758      C  Naypyidaw        Normal    Male    Health and beauty
# 965  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 966  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 967  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 968  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity  Tax 5%    Total       Date   Time  Payment    cogs  \
# 964       40.35         1  20.175  423.675 2019-01-29  13:46  Ewallet   40.35
# 965       97.38        10  48.690  1022.49 2019-03-02  17:16  Ewallet  973.80
# 966       31.84         1   1.592   33.432 2019-02-09  13:22     Cash   31.84
# 967       65.82         1   3.291   69.111 2019-02-22  15:33     Cash   65.82
# 968       88.34         7  30.919  649.299 2019-02-18  13:28     Cash  618.38
#
# ...

# %%
# visualizando o total de linhas e colunas]
df.shape
# Out:
# (969, 17)

# %%
# Retornando apenas os nomes das colunas
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
# Identificar o tipo de dado de cada coluna
df.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                              object
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage            object
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
# Outra opção -> mais informações
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 969 entries, 0 to 968
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               969 non-null    object
#  1   Branch                   969 non-null    object
#  2   City                     969 non-null    object
#  3   Customer type            969 non-null    object
#  4   Gender                   969 non-null    object
#  5   Product line             969 non-null    object
#  6   Unit price               969 non-null    float64
#  7   Quantity                 969 non-null    int64
#  8   Tax 5%                   969 non-null    float64
#  9   Total                    969 non-null    object
#  10  Date                     969 non-null    datetime64[ns]
#  11  Time                     969 non-null    object
#  12  Payment                  969 non-null    object
#  13  cogs                     969 non-null    float64
# ...

# %%
# Visualizando apenas uma coluna
df["Gender"]
# Out:
# 0      Female
# 1      Female
# 2        Male
# 3        Male
# 4        Male
#         ...
# 964      Male
# 965    Female
# 966      Male
# 967      Male
# 968    Female
# Name: Gender, Length: 969, dtype: object

# %%
# Visualizando a quantidade de valores unicos em uma coluna
df["Gender"].nunique()
# Out:
# 2

# %%
# Visualizando quais são os valores uncios
df["Gender"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
# Numero de vezes que aparece cada cidade
df['City'].value_counts()
# Out:
# Yangon       332
# Naypyidaw    319
# Mandalay     318
# Name: City, dtype: int64

# %%
# Selecinando uma amostra de dados(aleatoriamente)
df.sample(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 906  361-85-2571      A     Yangon        Normal  Female
# 955  764-44-8999      B   Mandalay        Normal  Female
# 303  174-36-3675      C  Naypyidaw        Member    Male
# 642  714-02-3114      C  Naypyidaw        Normal  Female
# 842  544-55-9589      B   Mandalay        Member  Female
#
#                Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 906       Sports and travel       89.48         5  22.370   469.77 2019-03-30
# 955       Health and beauty       14.76         2   1.476   30.996 2019-02-18
# 303      Food and beverages       99.37         2   9.937  208.677 2019-02-14
# 642       Sports and travel       98.80         2   9.880   207.48 2019-02-21
# 842  Electronic accessories       21.43        10  10.715  225.015 2019-01-28
#
#       Time  Payment    cogs gross margin percentage  gross income  Rating
# 906  10:18     Cash  447.40           4.761.904.762        22.370     7.4
# ...

# %%
# Retornando a data mais antiga
df['Date'].min()
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
# MAxima
df['Date'].max()
# Out:
# Timestamp('2019-03-30 00:00:00')

# %%
# Top 5 vendas pela quantidade de produtos vendidos(Quantity)
df.nlargest(5, "Quantity")["Quantity"]
# Index quantidade
# Out:
# 7     10
# 12    10
# 13    10
# 48    10
# 57    10
# Name: Quantity, dtype: int64

# %%
# Bottom 5 vendas pela quantidade de produtos vendidos
df.nsmallest(5, "Quantity")["Quantity"]
# Out:
# 25    1
# 34    1
# 39    1
# 52    1
# 67    1
# Name: Quantity, dtype: int64

# %%
# Ordenando um DataFrame por uma determinada coluna
df.sort_values("Total")  # ascending = False -> retorna em ordem decrescente
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 400  268-03-6164      B   Mandalay        Normal    Male
# 406  271-88-8734      C  Naypyidaw        Member  Female
# 765  744-16-7898      B   Mandalay        Normal  Female
# 480  401-18-8016      B   Mandalay        Member  Female
# 635  250-81-7186      C  Naypyidaw        Normal  Female
# ..           ...    ...        ...           ...     ...
# 750  875-31-8302      B   Mandalay        Normal    Male
# 365  182-69-8360      B   Mandalay        Normal  Female
# 804  343-75-9322      B   Mandalay        Member  Female
# 244  290-68-2984      A     Yangon        Normal    Male
# 785  674-56-6360      A     Yangon        Normal    Male
#
#                Product line  Unit price  Quantity  Tax 5%      Total  \
# 400       Health and beauty       96.11         1  48.055  1.009.155
# 406     Fashion accessories       97.21        10  48.605  1.020.705
# 765      Home and lifestyle       97.37        10  48.685  1.022.385
# ...

# %%
# total de produtos vendidos por branch( usaremso group by para agrupar valores de coluna iguais)
df.groupby("Branch")["Quantity"].sum()
# Out:
# Branch
# A    1806
# B    1743
# C    1778
# Name: Quantity, dtype: int64

# %%
# Media de produtos vendidos por branch
df.groupby("Branch")["Quantity"].mean()
# Out:
# Branch
# A    5.439759
# B    5.481132
# C    5.573668
# Name: Quantity, dtype: float64

# %%
# Fazendo um novo df a partir de groupby
df2 = df.groupby("Branch")["Quantity"].mean().reset_index()
df2
# Out:
#   Branch  Quantity
# 0      A  5.439759
# 1      B  5.481132
# 2      C  5.573668

# %% [markdown]
# # FILTROS EM PANDAS

# %%
# Filtrar vendas por sexo
df[df["Gender"] == "Female"].head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyidaw        Normal  Female
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyidaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%      Total  \
# 0       Health and beauty       74.69         7  261.415  5.489.715
# 1  Electronic accessories       15.28         5    3.820      80.22
# 6  Electronic accessories       68.84         6   20.652    433.692
# 7      Home and lifestyle       73.56        10   36.780     772.38
# 8       Health and beauty       36.26         2    3.626     76.146
#
#         Date   Time      Payment    cogs gross margin percentage  \
# 0 2019-01-05  13:08      Ewallet  522.83           4.761.904.762
# 1 2019-03-08  10:29         Cash   76.40           4.761.904.762
# ...

# %%
# Outra forma
df.loc[(df["Gender"] == "Female")].head(4)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyidaw        Normal  Female
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyidaw        Normal  Female
#
#              Product line  Unit price  Quantity   Tax 5%      Total  \
# 0       Health and beauty       74.69         7  261.415  5.489.715
# 1  Electronic accessories       15.28         5    3.820      80.22
# 6  Electronic accessories       68.84         6   20.652    433.692
# 7      Home and lifestyle       73.56        10   36.780     772.38
#
#         Date   Time  Payment    cogs gross margin percentage  gross income  \
# 0 2019-01-05  13:08  Ewallet  522.83           4.761.904.762       261.415
# 1 2019-03-08  10:29     Cash   76.40           4.761.904.762         3.820
# 6 2019-02-25  14:36  Ewallet  413.04           4.761.904.762        20.652
# ...

# %%
# Filtro duplo  ->  
# And: &
# ou: |
df.loc[(df["Gender"] == "Female") | (["City"] == "Yangon")].head(4)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyidaw        Normal  Female
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyidaw        Normal  Female
#
#              Product line  Unit price  Quantity   Tax 5%      Total  \
# 0       Health and beauty       74.69         7  261.415  5.489.715
# 1  Electronic accessories       15.28         5    3.820      80.22
# 6  Electronic accessories       68.84         6   20.652    433.692
# 7      Home and lifestyle       73.56        10   36.780     772.38
#
#         Date   Time  Payment    cogs gross margin percentage  gross income  \
# 0 2019-01-05  13:08  Ewallet  522.83           4.761.904.762       261.415
# 1 2019-03-08  10:29     Cash   76.40           4.761.904.762         3.820
# 6 2019-02-25  14:36  Ewallet  413.04           4.761.904.762        20.652
# ...

# %%
# isin -> pega os valores cuja alguma coluna X esta dentro dos valores do ISIN
lista = ["A", "B"]
df[df["Branch"].isin(lista)].head(4)
# Out:
#     Invoice ID Branch    City Customer type  Gender        Product line  \
# 0  750-67-8428      A  Yangon        Member  Female   Health and beauty
# 2  631-41-3108      A  Yangon        Normal    Male  Home and lifestyle
# 3  123-19-1176      A  Yangon        Member    Male   Health and beauty
# 4  373-73-7910      A  Yangon        Normal    Male   Sports and travel
#
#    Unit price  Quantity   Tax 5%      Total       Date   Time      Payment  \
# 0       74.69         7  261.415  5.489.715 2019-01-05  13:08      Ewallet
# 2       46.33         7  162.155  3.405.255 2019-03-03  13:23  Credit card
# 3       58.22         8   23.288    489.048 2019-01-27  20:33      Ewallet
# 4       86.31         7  302.085  6.343.785 2019-02-08  10:37      Ewallet
#
#      cogs gross margin percentage  gross income  Rating
# 0  522.83           4.761.904.762       261.415     9.1
# 2  324.31           4.761.904.762       162.155     7.4
# 3  465.76           4.761.904.762        23.288     8.4
# ...

# %%
# Not isin
lista = ["A", "B"]
df[~df["Branch"].isin(lista)].head(4)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 1   226-31-3081      C  Naypyidaw        Normal  Female
# 5   699-14-3026      C  Naypyidaw        Normal    Male
# 7   315-22-5665      C  Naypyidaw        Normal  Female
# 19  300-71-4605      C  Naypyidaw        Member    Male
#
#               Product line  Unit price  Quantity   Tax 5%      Total  \
# 1   Electronic accessories       15.28         5    3.820      80.22
# 5   Electronic accessories       85.39         7  298.865  6.276.165
# 7       Home and lifestyle       73.56        10   36.780     772.38
# 19  Electronic accessories       86.04         5   21.510     451.71
#
#          Date   Time  Payment    cogs gross margin percentage  gross income  \
# 1  2019-03-08  10:29     Cash   76.40           4.761.904.762         3.820
# 5  2019-03-25  18:30  Ewallet  597.73           4.761.904.762       298.865
# 7  2019-02-24  11:38  Ewallet  735.60           4.761.904.762        36.780
# ...

# %%
# Como fazer uma copia do dataframe
df_copia = df.copy()

# %%
# Como remover uma coluna em um dataframe(usar inplace para apagar em memoria(permanentemente))
df_copia.drop(columns="City").head(4)
# Out:
#     Invoice ID Branch Customer type  Gender            Product line  \
# 0  750-67-8428      A        Member  Female       Health and beauty
# 1  226-31-3081      C        Normal  Female  Electronic accessories
# 2  631-41-3108      A        Normal    Male      Home and lifestyle
# 3  123-19-1176      A        Member    Male       Health and beauty
#
#    Unit price  Quantity   Tax 5%      Total       Date   Time      Payment  \
# 0       74.69         7  261.415  5.489.715 2019-01-05  13:08      Ewallet
# 1       15.28         5    3.820      80.22 2019-03-08  10:29         Cash
# 2       46.33         7  162.155  3.405.255 2019-03-03  13:23  Credit card
# 3       58.22         8   23.288    489.048 2019-01-27  20:33      Ewallet
#
#      cogs gross margin percentage  gross income  Rating
# 0  522.83           4.761.904.762       261.415     9.1
# 1   76.40           4.761.904.762         3.820     9.6
# 2  324.31           4.761.904.762       162.155     7.4
# ...

# %% [markdown]
# # Visuzalização de dados com pandas
# https://www.data-to-viz.com/

# %%
# Total de linhas por gender(grafico pizza)
df["Gender"].value_counts().plot.pie();

# %%
# Adicionando o percentural
df["Gender"].value_counts().plot.pie(autopct="%1.2f%%");

# %%
# Grafico de barras
df["Gender"].value_counts().plot.bar();

# %%
df.head(4)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyidaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
#
#              Product line  Unit price  Quantity   Tax 5%      Total  \
# 0       Health and beauty       74.69         7  261.415  5.489.715
# 1  Electronic accessories       15.28         5    3.820      80.22
# 2      Home and lifestyle       46.33         7  162.155  3.405.255
# 3       Health and beauty       58.22         8   23.288    489.048
#
#         Date   Time      Payment    cogs gross margin percentage  \
# 0 2019-01-05  13:08      Ewallet  522.83           4.761.904.762
# 1 2019-03-08  10:29         Cash   76.40           4.761.904.762
# 2 2019-03-03  13:23  Credit card  324.31           4.761.904.762
# 3 2019-01-27  20:33      Ewallet  465.76           4.761.904.762
#
# ...

# %%
# Total de produtos vendidos por linha de produtos
df.groupby("Product line")["Quantity"].sum().plot.bar()
# Out:
# <Axes: xlabel='Product line'>

# %%
# Colocando o grafico em ordem(por mais vendido)
df.groupby("Product line")["Quantity"].sum().sort_values(ascending=False).plot.bar()
# Out:
# <Axes: xlabel='Product line'>

# %%
# Invertendo os eixos e dando nome aos bois
df.groupby("Product line")["Quantity"].sum().sort_values(ascending=True).plot.barh(title="Total de produtos vendidos por linha de produto")
plt.xlabel('Total de produtos vendidos')
plt.ylabel("categoria de produto")
# Out:
# Text(0, 0.5, 'categoria de produto')

# %%
# Colocando rotulos de dados em matplotlib
dados = df.groupby("Product line")["Quantity"].sum().sort_values(ascending=True).reset_index()
fig, ax= plt.subplots()
p1 = ax.bar("Product line", "Quantity", data=dados)
ax.set_title("total produto vendidos")
plt.xticks(fontsize=8, rotation=20)
ax.bar_label(p1);

# %%
# Alterando o estilo: https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
plt.style.use('ggplot')

# %%
df.groupby("Product line")["Quantity"].sum().sort_values(ascending=True).plot.barh(title="Total de produtos vendidos por linha de produto", color="blue")
plt.xlabel('Total de produtos vendidos')
plt.ylabel("categoria de produto")
# Out:
# Text(0, 0.5, 'categoria de produto')

# %% [markdown]
# # Usando plotly

# %%
dados
# Out:
#              Product line  Quantity
# 0       Health and beauty       827
# 1     Fashion accessories       864
# 2      Home and lifestyle       873
# 3       Sports and travel       894
# 4      Food and beverages       931
# 5  Electronic accessories       938

# %%
import plotly.express as px

# %%
fig = px.bar(dados, x = "Quantity", y="Product line", orientation="h") # vai criar o grafico horizontalmente
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Desafio:  Corrigir dados do total para float64
