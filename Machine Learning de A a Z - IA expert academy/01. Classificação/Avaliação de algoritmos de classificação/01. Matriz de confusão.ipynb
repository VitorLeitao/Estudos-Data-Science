# %% [markdown]
# # Matriz de confusão

# %% [markdown]
# ![maxresdefault.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Verdadeiro positivo e falso positivo

# %% [markdown]
# ![matrizConfusao-600x381.png](data:image/png;base64,...)

# %% [markdown]
# - não devemos nos basear sempre apenas no accuracy
# - a depender do projeto em questao, devemos dar prioriadade a Falsos negativos ou falsos positivos, dando um foco no que for mais importante no projeto.

# %% [markdown]
# # precision e recall

# %% [markdown]
# - PRECISION:
# - quando o modelo previu **SIM**, o quanto o modelo estava certo?? ->> TP(TP + FP)
# - RECALL:
# - quando o valor verdadeiro é **SIM**, o quanto o modelo classificou corretamente?? --> TP / TP + FN

# %% [markdown]
# # Validação cruzada

# %% [markdown]
# - tecnica mais utilizada para fazer validações de algoritmos
# - Todos os registos são usados tanto para testar quanto para treinar, evitando a exclusão de registros importantes no treinamento

# %% [markdown]
# ![Kfold_Resultados.png](data:image/png;base64,...)

# %% [markdown]
# # Overfitting e Underfitting

# %% [markdown]
# - Underfitting --> usando algoritmo muito basico para problema muito complexo
# - Overfitting --> Muitos recursos para problemas simples
# - Underffiting é quando fazemos uma coisa muito basica para um problema complexo, enquanto overfitting, é quando superestimamos um problema, quando se especifica demais na base de treinamento e nao consegue sair disso, ficando limitado a ela, gerando assim diversos erros em dados fora da base
#
# - o underffiting tem resultados ruins na base de treinamento, enquanto o overffiting tem bons resultados na base de treinamento, mas **nao consegue generalizar o modelo**
